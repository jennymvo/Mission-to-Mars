# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 96.0.4664
# [WDM] - Get LATEST driver version for 96.0.4664
# [WDM] - Driver [/Users/kulini/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache

# %%
url = "https://globalvoices.org/page/2/"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box
browser.links.find_by_partial_text("No thanks").click()

# %%
# List to contain article info
articles_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    main_area = soup.find("div", class_="post-archive-container")
    articles = main_area.find_all("div", class_="gv-promo-card-text")
    
    for article in articles:
        header = article.find("h3", class_="post-title").text.strip()
        date = article.find("span", class_="datestamp")["title"]
        date = date.replace('_', '')
        
        
        summary_dict = {
            "header": header,
            "date": date
        }
        articles_list.append(summary_dict)

# %%
for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text("Older").click()

# %%
articles_list
# Out:
# [{'header': 'Portugal: Human rights activist fighting racism wins international award',
#   'date': '29 12 2021'},
#  {'header': 'Where is Qatari human rights defender Noof Al-Maadeed?',
#   'date': '29 12 2021'},
#  {'header': '10 stories on Black and Indigenous identity from Latin America in 2021',
#   'date': '29 12 2021'},
#  {'header': 'Barbados prime minister calls a snap election, the first poll for the island as a republic',
#   'date': '29 12 2021'},
#  {'header': 'Hong Kong police raid pro-democracy Stand News, arrest six on sedition charges',
#   'date': '29 12 2021'},
#  {'header': 'The return of the rufous-necked hornbill to Nepal',
#   'date': '29 12 2021'},
#  {'header': '2021: A fruitful year for Indigenous communities in Taiwan',
#   'date': '29 12 2021'},
#  {'header': 'Indigenous community radio operators win court case against the Guatemalan State',
#   'date': '28 12 2021'},
#  {'header': 'The untold story of a young Colombian Indigenous reporter, guardian and hairdresser',
#   'date': '28 12 2021'},
#  {'header': 'Ukraine to get support from Apple with conducting national census in 2023',
#   'date': '28 12 2021'},
#  {'header': 'Exploitation of Indian migrant workers in Serbia continues',
#   'date': '28 12 2021'},
#  {'header': 'Russian censors block website of legal aid non-profit OVD-Info',
#   'date': '27 12 2021'},
#  {'header': 'Indian migrant workers fight for their right to get paid in Serbia',
#   'date': '27 12 2021'},
#  {'header': "Twitter ignores Malaysian government's request to censor Tweets about flood response",
#   'date': '26 12 2021'},
#  {'header': 'Portraits of a pandemic: Films on the unequal impact of COVID-19 in the Asia-Pacific',
#   'date': '24 12 2021'},
#  {'header': 'Lebanon to deport Bahraini opposition Al-Wefaq members in unprecedented move',
#   'date': '24 12 2021'},
#  {'header': 'Serbian authorities accused of spying on visiting Russian citizens at behest of Kremlin',
#   'date': '23 12 2021'},
#  {'header': 'Hong Kong: Pillar of Shame is gone, along with the city’s freedom of expression',
#   'date': '23 12 2021'},
#  {'header': 'Not just ‘Jingle Bells:’ Listen to these Christmas songs from Latin America',
#   'date': '22 12 2021'},
#  {'header': "‘The Club,’ Netflix's new hit TV series, braves Turkey's troubled past",
#   'date': '22 12 2021'},
#  {'header': 'In Russia, an ongoing battle for the future of science',
#   'date': '21 12 2021'},
#  {'header': 'Malawian scientist who forewarned about Omicron-type variant speaks out',
#   'date': '21 12 2021'},
#  {'header': 'Turkish pop star angers the public with tone-deaf comments on current economic crisis',
#   'date': '21 12 2021'},
#  {'header': 'Turkey announces new steps to normalize ties with Armenia',
#   'date': '20 12 2021'},
#  {'header': 'The Turkish Lira continues to lose value at a breakneck pace',
#   'date': '20 12 2021'},
#  {'header': "A certificate for grazing cattle: Empowering Bolivia's Aymara people by recognizing their work",
#   'date': '20 12 2021'},
#  {'header': 'Hong Kong sees record-low voter turnout in its ‘patriot-only’ Legislative Council elections',
#   'date': '20 12 2021'},
#  {'header': 'Russian peacekeepers promise to oversee return of all Armenian prisoners held in Azerbaijan',
#   'date': '20 12 2021'},
#  {'header': 'Top human rights court finds that the Georgia government violated the European Convention on Human Rights',
#   'date': '20 12 2021'},
#  {'header': 'The International Court of Justice orders Armenia and Azerbaijan to prevent racial hatred',
#   'date': '20 12 2021'},
#  {'header': "China's top propagandist Hu Xijin steps down as The Global Times’ chief editor",
#   'date': '20 12 2021'},
#  {'header': '2021 in review, from a Caribbean point of view',
#   'date': '20 12 2021'},
#  {'header': 'Turkish prosecutor general closes investigation into death of Azerbaijan’s ‘graffiti prisoner,’ Bayram Mammadov',
#   'date': '19 12 2021'},
#  {'header': 'New Caledonia votes to stay with France in referendum boycotted by the Indigenous population',
#   'date': '18 12 2021'},
#  {'header': 'Georgian authorities fail to produce autopsy five months after journalist’s death',
#   'date': '18 12 2021'},
#  {'header': 'In Nigeria, the government weaponises the law against online expression',
#   'date': '17 12 2021'},
#  {'header': 'Undertones: Online violence in Myanmar, Pakistan’s smog cover-up',
#   'date': '17 12 2021'},
#  {'header': 'Despite updates in legislation, organisations in Uganda struggle with data protection and privacy compliance',
#   'date': '17 12 2021'},
#  {'header': '2021 in retrospective: Authoritarian practices threatened journalists and restricted media freedom in South Asia',
#   'date': '16 12 2021'},
#  {'header': 'Tunisia: New prosecutions resurrect shadow of dictatorship',
#   'date': '16 12 2021'},
#  {'header': 'In Sudan, the court stands on the side of unrestricted access to the internet',
#   'date': '16 12 2021'},
#  {'header': 'July 7 declared World Kiswahili Language Day: A new project seeks to better understand present day dialectal variations in Swahili',
#   'date': '15 12 2021'},
#  {'header': "Lost and found: Repatriation of Laxmi-Narayan's statue to Kathmandu Valley’s Patan",
#   'date': '15 12 2021'},
#  {'header': 'SMEX: Israel’s presence at Expo Dubai 2020 Is a threat to digital rights',
#   'date': '15 12 2021'},
#  {'header': 'How did Vietnam do on human rights in 2021?',
#   'date': '15 12 2021'},
#  {'header': 'Mozambican government reacts to conflict by imposing its own digital narratives',
#   'date': '14 12 2021'},
#  {'header': 'Russian filmmaker Sergei Solovyov dies at 77',
#   'date': '14 12 2021'},
#  {'header': 'In the midst of floods and climate change, these are the local systems that hold the fabric of Assam together',
#   'date': '14 12 2021'},
#  {'header': "The ‘immoral’ 42 songs banned from Indonesia's daytime radio",
#   'date': '14 12 2021'},
#  {'header': 'Arrest of activist Khurram Parvez shows ‘a new hostility towards civil society in Kashmir’',
#   'date': '14 12 2021'},
#  {'header': 'Myanmar’s ‘silent strike’ delivers loud condemnation of continuing military rule',
#   'date': '14 12 2021'},
#  {'header': 'St Lucia announces it will host a ‘vaxxed’ Carnival in 2022, but is it realistic?',
#   'date': '13 12 2021'},
#  {'header': 'Namibian activists maximize social media to expose unlawful jurisdiction and homophobic legislature',
#   'date': '13 12 2021'},
#  {'header': 'Agroecology, Nepal’s answer to climate change',
#   'date': '12 12 2021'},
#  {'header': 'In photos: Could the mountains of the Caribbean be an opportunity for sustainable tourism?',
#   'date': '11 12 2021'},
#  {'header': 'Zagreb protests: Croatians divided around COVID-19 certificates',
#   'date': '11 12 2021'},
#  {'header': 'International media watchdog digs into the ‘great leap backwards’ of journalism in China',
#   'date': '10 12 2021'},
#  {'header': "Push to stop it: Anti-harassment buttons appear in Uzbekistan's buses",
#   'date': '9 12 2021'},
#  {'header': 'How new generations are reinventing antifascism in Bosnia and Herzegovina',
#   'date': '9 12 2021'},
#  {'header': "‘Unmatched’ and ‘irreplaceable': Jamaica’s iconic bassist, Robbie Shakespeare, has died",
#   'date': '9 12 2021'},
#  {'header': "How ‘cyber troops’ influence Indonesia's politics, policies, and media landscape",
#   'date': '9 12 2021'},
#  {'header': 'The Uranw of Nepal seek official recognition of their Karma Festival',
#   'date': '9 12 2021'},
#  {'header': 'Russia blocks access to Tor browser website',
#   'date': '8 12 2021'},
#  {'header': 'Uganda holds regional e-conference on unpaid care work',
#   'date': '8 12 2021'},
#  {'header': 'High infection, low vaccination—could mandatory COVID-19 vaccines be the answer for Caribbean nations?',
#   'date': '8 12 2021'},
#  {'header': 'Changes on the Global Voices board', 'date': '7 12 2021'},
#  {'header': 'The US government confirms diplomatic boycott of 2022 Beijing Winter Olympics',
#   'date': '7 12 2021'},
#  {'header': 'Undertones: A deep-dive into Indian hyper-nationalism',
#   'date': '6 12 2021'},
#  {'header': 'Death and destruction as former allies faced off in central Somalia',
#   'date': '6 12 2021'},
#  {'header': 'Citizens start clean-up and recovery efforts after protests and riots in Solomon Islands',
#   'date': '6 12 2021'},
#  {'header': 'Hong Kong authorities warn against boycott campaigns over low voter interest ahead of Legislative Elections',
#   'date': '6 12 2021'},
#  {'header': 'Post-COP26, a Caribbean view on climate injustice and ‘1.5 to stay alive’',
#   'date': '5 12 2021'},
#  {'header': 'Omicron prompts Japan to attempt “national isolation” once more',
#   'date': '4 12 2021'},
#  {'header': 'Belarus, transformed: political analysts track social and political change in the country',
#   'date': '4 12 2021'},
#  {'header': 'Indonesian police arrested students who raised banned ‘Papuan Independence Day’ flag',
#   'date': '3 12 2021'},
#  {'header': 'Popular, yet banned, songs in Cuba', 'date': '2 12 2021'},
#  {'header': 'Artist collective rekindles Argentine folklore from a queer perspective',
#   'date': '2 12 2021'},
#  {'header': "Taiwan’s Golden Horse Film Awards highlights Hong Kong's censored productions",
#   'date': '2 12 2021'},
#  {'header': 'Protest in support of jailed opposition activist in Baku turns violent',
#   'date': '1 12 2021'},
#  {'header': 'Colonial prejudices and vaccine nationalism drive COVID-19 African travel bans',
#   'date': '1 12 2021'},
#  {'header': 'Armenia’s ex-president Serzh Sargsyan faces bribery charges',
#   'date': '1 12 2021'},
#  {'header': 'Georgian Communications Commission levies fines on TV channels for ‘political’ content',
#   'date': '1 12 2021'},
#  {'header': 'Armenia and Azerbaijan pledge progress as leaders meet in Sochi',
#   'date': '1 12 2021'},
#  {'header': "Turkey's Medical professionals call for better working conditions",
#   'date': '1 12 2021'},
#  {'header': "Barbados becomes the world's newest republic",
#   'date': '1 12 2021'},
#  {'header': 'A century of Etel Adnan: a mountain who leaves behind mountains',
#   'date': '30 11 2021'},
#  {'header': "With Ukraine's Kyiv Post shut down, journalists launch new independent media outlet",
#   'date': '30 11 2021'},
#  {'header': 'As shorebird populations drastically decline in the French Caribbean, hunting traditions persist',
#   'date': '30 11 2021'},
#  {'header': 'Artist Jasmine Thomas-Girvan taps into the ‘eternal connections’ of Black Caribbean ancestry',
#   'date': '30 11 2021'},
#  {'header': "Jamaicans mourn the passing of human rights defender Nancy Anderson, who worked to assist the island's most vulnerable citizens",
#   'date': '30 11 2021'},
#  {'header': 'Digital panaceas for an analog world', 'date': '30 11 2021'},
#  {'header': 'Making Turkish music in Hungary: Can this be a ‘Nasip Kısmet’ moment?',
#   'date': '29 11 2021'},
#  {'header': 'In Azerbaijan, bullying in schools is still a problem',
#   'date': '29 11 2021'},
#  {'header': 'Barbados forges a digital path by becoming the first country to establish an embassy in the metaverse',
#   'date': '29 11 2021'},
#  {'header': 'Afghan women: Finally a book that speaks from inside its society',
#   'date': '29 11 2021'},
#  {'header': 'In Turkey women faced rubber bullets, tear gas from police as they marched to end gender-based violence',
#   'date': '29 11 2021'},
#  {'header': 'Uzbekistan and Kazakhstan tighten the screws on media freedom',
#   'date': '29 11 2021'},
#  {'header': 'Jamaica officially recognises the life and legacy of iconic wartime nurse, Mary Seacole',
#   'date': '29 11 2021'},
#  {'header': 'An interview with media scholar Rose Luqiu about WeChat and techno-nationalism',
#   'date': '29 11 2021'},
#  {'header': "‘In my country, I feared the war. But here I feared the Home Office': Asylum seekers speak on the UK refugee process",
#   'date': '29 11 2021'},
#  {'header': 'Human-elephant conflict could lead to the extinction of elephants in Bangladesh',
#   'date': '28 11 2021'},
#  {'header': 'Cambodian rapper vows to continue writing critical songs after a year in jail for incitement',
#   'date': '28 11 2021'},
#  {'header': 'France complicit in heinous crimes committed by Egyptian state, website reveals',
#   'date': '28 11 2021'},
#  {'header': 'Press freedom and the Indian judiciary', 'date': '26 11 2021'},
#  {'header': "‘Unfit for military service':\xa0How Azerbaijan stigmatizes LGBTQ+ military personnel",
#   'date': '26 11 2021'}]

# %%
import pandas as pd
df = pd.DataFrame(articles_list)
df.head()
# Out:
#                                               header        date
# 0  Portugal: Human rights activist fighting racis...  29 12 2021
# 1  Where is Qatari human rights defender Noof Al-...  29 12 2021
# 2  10 stories on Black and Indigenous identity fr...  29 12 2021
# 3  Barbados prime minister calls a snap election,...  29 12 2021
# 4  Hong Kong police raid pro-democracy Stand News...  29 12 2021

# %%
df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#                                                 header       date
# 0    Portugal: Human rights activist fighting racis... 2021-12-29
# 1    Where is Qatari human rights defender Noof Al-... 2021-12-29
# 2    10 stories on Black and Indigenous identity fr... 2021-12-29
# 3    Barbados prime minister calls a snap election,... 2021-12-29
# 4    Hong Kong police raid pro-democracy Stand News... 2021-12-29
# ..                                                 ...        ...
# 100  Human-elephant conflict could lead to the exti... 2021-11-28
# 101  Cambodian rapper vows to continue writing crit... 2021-11-28
# 102  France complicit in heinous crimes committed b... 2021-11-28
# 103             Press freedom and the Indian judiciary 2021-11-26
# 104  ‘Unfit for military service': How Azerbaijan s... 2021-11-26
#
# [105 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   header  105 non-null    object
#  1   date    105 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.8+ KB

# %%
browser.quit()
